# %% [markdown]
# <a href="https://colab.research.google.com/github/shibbolithic/AmazonMLhack/blob/main/Untitled22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# Define the base path to the directory containing the files
base_path = '/content/drive/MyDrive/dataset (1)/'

# Load the DataFrames
train_df = pd.read_csv(base_path + 'train.csv')
test_df = pd.read_csv(base_path + 'test.csv')
sample_test_df = pd.read_csv(base_path + 'sample_test.csv')
sample_test_out_df = pd.read_csv(base_path + 'sample_test_out.csv')

# Verify the loading
print("Train DataFrame shape:", train_df.shape)
print("Test DataFrame shape:", test_df.shape)
# Out:
# Train DataFrame shape: (75000, 4)
# Test DataFrame shape: (75000, 3)

# %%
train_df
# Out:
#        sample_id                                    catalog_content  \
# 0          33127  Item Name: La Victoria Green Taco Sauce Mild, ...
# 1         198967  Item Name: Salerno Cookies, The Original Butte...
# 2         261251  Item Name: Bear Creek Hearty Soup Bowl, Creamy...
# 3          55858  Item Name: Judee’s Blue Cheese Powder 11.25 oz...
# 4         292686  Item Name: kedem Sherry Cooking Wine, 12.7 Oun...
# ...          ...                                                ...
# 74995      41424  Item Name: ICE BREAKERS Spearmint Sugar Free M...
# 74996      35537  Item Name: Davidson's Organics, Vanilla Essenc...
# 74997     249971  Item Name: Jolly Rancher Hard Candy - Blue Ras...
# 74998     188322  Item Name: Nescafe Dolce Gusto Capsules - CARA...
# 74999     298504  Item Name: Pimenton de la Vera - Picante (2.47...
#
#                                               image_link   price
# 0      https://m.media-amazon.com/images/I/51mo8htwTH...   4.890
# ...

# %%
pip install lightgbm scikit-learn pandas numpy matplotlib seaborn

# %%
train_df.head()
# Out:
#    sample_id                                    catalog_content  \
# 0      33127  Item Name: La Victoria Green Taco Sauce Mild, ...
# 1     198967  Item Name: Salerno Cookies, The Original Butte...
# 2     261251  Item Name: Bear Creek Hearty Soup Bowl, Creamy...
# 3      55858  Item Name: Judee’s Blue Cheese Powder 11.25 oz...
# 4     292686  Item Name: kedem Sherry Cooking Wine, 12.7 Oun...
#
#                                           image_link  price
# 0  https://m.media-amazon.com/images/I/51mo8htwTH...   4.89
# 1  https://m.media-amazon.com/images/I/71YtriIHAA...  13.12
# 2  https://m.media-amazon.com/images/I/51+PFEe-w-...   1.97
# 3  https://m.media-amazon.com/images/I/41mu0HAToD...  30.34
# 4  https://m.media-amazon.com/images/I/41sA037+Qv...  66.49

# %%
# Drop duplicates
train_df.drop_duplicates(subset=['catalog_content', 'image_link'], inplace=True)

# Handle missing values
train_df['catalog_content'] = train_df['catalog_content'].fillna("unknown product")
test_df['catalog_content'] = test_df['catalog_content'].fillna("unknown product")

train_df['image_link'] = train_df['image_link'].fillna("")
test_df['image_link'] = test_df['image_link'].fillna("")

print(train_df.isna().sum())
# Out:
# sample_id          0
# catalog_content    0
# image_link         0
# price              0
# dtype: int64

# %%
import re

def clean_text(text):
    text = text.lower()
    text = re.sub(r'[^a-z0-9\s]', '', text)
    text = re.sub(r'\s+', ' ', text).strip()
    return text

train_df['clean_text'] = train_df['catalog_content'].apply(clean_text)
test_df['clean_text'] = test_df['catalog_content'].apply(clean_text)

train_df[['catalog_content','clean_text']].head(3)
# Out:
#                                      catalog_content  \
# 0  Item Name: La Victoria Green Taco Sauce Mild, ...
# 1  Item Name: Salerno Cookies, The Original Butte...
# 2  Item Name: Bear Creek Hearty Soup Bowl, Creamy...
#
#                                           clean_text
# 0  item name la victoria green taco sauce mild 12...
# 1  item name salerno cookies the original butter ...
# 2  item name bear creek hearty soup bowl creamy c...

# %%
print("Price Summary:")
print(train_df['price'].describe())

train_df['text_length'] = train_df['clean_text'].apply(len)
train_df['text_length'].hist(bins=50)
# Out:
# Price Summary:
# count    74954.000000
# mean        23.650088
# std         33.380076
# min          0.130000
# 25%          6.800000
# 50%         14.000000
# 75%         28.633750
# max       2796.000000
# Name: price, dtype: float64
# <Axes: >

# %%
train_df.to_csv('/content/drive/MyDrive/SmartPricing/dataset/train_clean.csv', index=False)
test_df.to_csv('/content/drive/MyDrive/SmartPricing/dataset/test_clean.csv', index=False)

# %%
import torch
import numpy as np
from tqdm import tqdm
import pandas as pd
from PIL import Image
import requests
from io import BytesIO
import timm
from transformers import AutoTokenizer, AutoModel

# %%
train_df = pd.read_csv('/content/drive/MyDrive/SmartPricing/dataset/train_clean.csv')
test_df = pd.read_csv('/content/drive/MyDrive/SmartPricing/dataset/test_clean.csv')

print("Train shape:", train_df.shape)
# Out:
# Train shape: (74954, 6)

# %%
tokenizer = AutoTokenizer.from_pretrained("sentence-transformers/all-MiniLM-L6-v2")
text_model = AutoModel.from_pretrained("sentence-transformers/all-MiniLM-L6-v2")

def get_text_embedding(text):
    inputs = tokenizer(text, return_tensors="pt", truncation=True, padding=True, max_length=128)
    with torch.no_grad():
        outputs = text_model(**inputs)
        emb = outputs.last_hidden_state.mean(dim=1)
    return emb.squeeze().numpy()
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]

# %%
def get_text_embeddings_batch(texts, batch_size=32):
    embeddings = []
    for i in tqdm(range(0, len(texts), batch_size)):
        batch_texts = texts[i:i + batch_size]
        inputs = tokenizer(batch_texts, return_tensors="pt", truncation=True, padding=True, max_length=128)
        # Move inputs to GPU if available
        if torch.cuda.is_available():
            inputs = {k: v.to('cuda') for k, v in inputs.items()}

        with torch.no_grad():
            # Move model to GPU if available
            if torch.cuda.is_available():
              text_model.to('cuda')
            outputs = text_model(**inputs)
            emb = outputs.last_hidden_state.mean(dim=1)
        embeddings.append(emb.cpu().numpy()) # Move embeddings back to CPU

    return np.concatenate(embeddings, axis=0)

train_text_emb = get_text_embeddings_batch(train_df['clean_text'].tolist())
# Out:
# 100%|██████████| 74954/74954 [49:07<00:00, 25.43it/s]

# %%
np.save('/content/drive/MyDrive/SmartPricing/dataset/train_text_emb.npy', train_text_emb)

# %%
test_embeddings = []
for t in tqdm(test_df['clean_text'].tolist()):
    test_embeddings.append(get_text_embedding(t))

test_text_emb = np.array(test_embeddings)
# Out:
#   6%|▌         | 4409/75000 [02:50<56:48, 20.71it/s]

# %%
np.save('/content/drive/MyDrive/SmartPricing/dataset/test_text_emb.npy', test_text_emb)

# %%
import torchvision.transforms as transforms

# Pretrained CNN model
image_model = timm.create_model('efficientnet_b0', pretrained=True)
image_model.eval()

# Transformation
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

def get_image_embedding(url):
    try:
        response = requests.get(url, timeout=5)
        img = Image.open(BytesIO(response.content)).convert('RGB')
        img = transform(img).unsqueeze(0)
        with torch.no_grad():
            features = image_model.forward_features(img)
            emb = features.mean(dim=[2,3]).squeeze().numpy()
        return emb
    except:
        # Return zero vector if download fails
        return np.zeros(1280)

# %%
image_embs = []
for link in tqdm(train_df['image_link'].tolist()[:500]):  # Start with first 500 for testing
    image_embs.append(get_image_embedding(link))

# %%
np.save('/content/drive/MyDrive/SmartPricing/dataset/train_image_emb_partial.npy', np.array(image_embs))

# %%
train_text_emb = np.load('/content/drive/MyDrive/SmartPricing/dataset/train_text_emb.npy')
train_image_emb = np.load('/content/drive/MyDrive/SmartPricing/dataset/train_image_emb_partial.npy')  # or full if done

X_train = np.concatenate([train_text_emb, train_image_emb], axis=1)
y_train = train_df['price'].values

print("Final feature shape:", X_train.shape)

# %%
test_text_emb = np.load('/content/drive/MyDrive/SmartPricing/dataset/test_text_emb.npy')
test_image_emb = np.load('/content/drive/MyDrive/SmartPricing/dataset/test_image_emb_partial.npy')

X_test = np.concatenate([test_text_emb, test_image_emb], axis=1)
